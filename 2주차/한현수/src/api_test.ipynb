# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request as ul
import xmltodict
import json
import io
# %matplotlib inline
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote

# %%
sys.version
# Out:
# '3.7.1 (default, Oct 28 2018, 08:39:03) [MSC v.1912 64 bit (AMD64)]'

# %%
import urllib.request

#-*- coding:utf-8 -*-
url = 'http://apis.data.go.kr/B553077/api/open/sdsc/storeZoneInRadius?radius=500&cx=127.004528&cy=37.567538&ServiceKey=bG%2BZ%2BmDdiTVy%2Faq2OLF%2FKCockUZQnuHoXbUTjrFJYWbe5ZtQ7qRAJgXoFYaG7YY7N7%2BLkPJhevA1Wy1wdeH%2FIw%3D%3D&type=json'
response = urllib.request.urlopen(url)

json_str = response.read().decode("utf-8")

# %%
import json
json_object = json.loads(json_str)
json_object
# Out:
# {'header': {'description': '소상공인시장진흥공단 주요상권',
#   'resultCode': '00',
#   'resultMsg': 'NORMAL SERVICE'},
#  'body': {'items': [{'trarNo': 2214,
#     'mainTrarNm': '을지로4가역',
#     'ctprvnCd': '11',
#     'ctprvnNm': '서울특별시',
#     'signguCd': '11140',
#     'signguNm': '중구',
#     'trarArea': 88434.9,
#     'coordNum': 8,
#     'coords': 'POLYGON ((126.999081 37.566789, 127.002102 37.566937, 127.001981 37.568644, 127.001871 37.568655, 127.001873 37.569521, 126.998065 37.568812, 126.998213 37.566753, 126.999081 37.566789))',
#     'stdrDt': '2015-12-17'},
#    {'trarNo': 2216,
#     'mainTrarNm': '동대문시장',
#     'ctprvnCd': '11',
#     'ctprvnNm': '서울특별시',
#     'signguCd': '11140',
#     'signguNm': '중구',
#     'trarArea': 68658,
#     'coordNum': 15,
# ...

# %%
import pandas as pd
from pandas.io.json import json_normalize

body = [json_object['body']['items']]
body
# Out:
# [[{'trarNo': 2214,
#    'mainTrarNm': '을지로4가역',
#    'ctprvnCd': '11',
#    'ctprvnNm': '서울특별시',
#    'signguCd': '11140',
#    'signguNm': '중구',
#    'trarArea': 88434.9,
#    'coordNum': 8,
#    'coords': 'POLYGON ((126.999081 37.566789, 127.002102 37.566937, 127.001981 37.568644, 127.001871 37.568655, 127.001873 37.569521, 126.998065 37.568812, 126.998213 37.566753, 126.999081 37.566789))',
#    'stdrDt': '2015-12-17'},
#   {'trarNo': 2216,
#    'mainTrarNm': '동대문시장',
#    'ctprvnCd': '11',
#    'ctprvnNm': '서울특별시',
#    'signguCd': '11140',
#    'signguNm': '중구',
#    'trarArea': 68658,
#    'coordNum': 15,
#    'coords': 'POLYGON ((127.009453 37.568775, 127.009445 37.569396, 127.009558 37.569397, 127.009543 37.569686, 127.00659 37.569553, 127.006688 37.568112, 127.007709 37.567931, 127.007098 37.567124, 127.006951 37.56706, 127.006146 37.56717, 127.005929 37.566438, 127.007632 37.56611, 127.008198 37.566935, 127.008107 37.566979, 127.009453 37.568775))',
# ...

# %%
json_normalize(json_object['body']['items'])
# Out:
#    coordNum                                             coords ctprvnCd  \
# 0         8  POLYGON ((126.999081 37.566789, 127.002102 37....       11
# 1        15  POLYGON ((127.009453 37.568775, 127.009445 37....       11
# 2         8  POLYGON ((127.007565 37.565945, 127.004846 37....       11
# 3        28  POLYGON ((127.009388 37.570565, 127.008984 37....       11
# 4        20  POLYGON ((127.001795 37.57082, 127.000088 37.5...       11
#
#   ctprvnNm      mainTrarNm signguCd signguNm      stdrDt  trarArea  trarNo
# 0    서울특별시          을지로4가역    11140       중구  2015-12-17   88434.9    2214
# 1    서울특별시           동대문시장    11140       중구  2015-12-17   68658.0    2216
# 2    서울특별시      동대문역사문화공원역    11140       중구  2015-12-17   81499.1    2207
# 3    서울특별시           동대문시장    11110      종로구  2015-12-17   82364.6    2226
# 4    서울특별시  서울 종로구 종로5가역_1    11110      종로구  2015-12-17   50246.7    2225
