# %%
# !pip3 install googlemaps
# Out:
# ...
#   Using cached googlemaps-4.4.5.tar.gz (31 kB)
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.4.5-py3-none-any.whl size=37988 sha256=d27b74bb8fb87fb8c1242f362d3fafeb0f76758d5006ef29b84d50f58a228462
#   Stored in directory: c:\users\chaeh\appdata\local\pip\cache\wheels\aa\52\df\fcc993a8582e4b3953e7217163b01c9ebcc36fe08f4090ba7e
# Successfully built googlemaps
# ...

# %%
import requests
import googlemaps
import json

# %%
gmaps = googlemaps.Client(key='AIzaSyDF4BCBwCWF1FVJV8hAS5nT8YQ-9xqZLLc')

# %%
def find_addr(location):
    geocode_result = gmaps.geocode(location, language='ko')
    print(geocode_result)

# %%
loc="서울시청 던킨도너츠"
find_addr(loc)
# Out:
# [{'address_components': [{'long_name': '３６０−１', 'short_name': '３６０−１', 'types': ['premise']}, {'long_name': '태평로2가', 'short_name': '태평로2가', 'types': ['political', 'sublocality', 'sublocality_level_2']}, {'long_name': '중구', 'short_name': '중구', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': '서울특별시', 'short_name': '서울특별시', 'types': ['administrative_area_level_1', 'political']}, {'long_name': '대한민국', 'short_name': 'KR', 'types': ['country', 'political']}, {'long_name': '100-102', 'short_name': '100-102', 'types': ['postal_code']}], 'formatted_address': '대한민국 서울특별시 중구 태평로2가 360-1', 'geometry': {'location': {'lat': 37.5646366, 'lng': 126.9766152}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 37.5659855802915, 'lng': 126.9779641802915}, 'southwest': {'lat': 37.5632876197085, 'lng': 126.9752662197085}}}, 'place_id': 'ChIJqSBFJ_OifDURoS7kzvThZ5Q', 'plus_code': {'compound_code': 'HX7G+VJ 대한민국 서울특별시', 'global_code': '8Q98HX7G+VJ'}, 'types': ['baker
# ...

# %%
reverse_geocode_result=  gmaps.reverse_geocode((37.5646366,126.9766152), language='ko')

# %%
## 예쁘게보려고
print(json.dumps(reverse_geocode_result,indent=2))
#print(reverse_geocode_result)
# Out:
# [
#   {
#     "address_components": [
#       {
#         "long_name": "\uff11\uff16\u2212\uff11\uff16",
#         "short_name": "\uff11\uff16\u2212\uff11\uff16",
#         "types": [
#           "premise"
#         ]
#       },
#       {
#         "long_name": "\ud654\uc591\ub3d9",
#         "short_name": "\ud654\uc591\ub3d9",
#         "types": [
#           "political",
#           "sublocality",
#           "sublocality_level_2"
#         ]
#       },
#       {
#         "long_name": "\uad11\uc9c4\uad6c",
#         "short_name": "\uad11\uc9c4\uad6c",
#         "types": [
#           "political",
#           "sublocality",
#           "sublocality_level_1"
#         ]
#       },
#       {
#         "long_name": "\uc11c\uc6b8\ud2b9\ubcc4\uc2dc",
#         "short_name": "\uc11c\uc6b8\ud2b9\ubcc4\uc2dc",
#         "types": [
#           "administrative_area_level_1",
#           "political"
#         ]
#       },
#       {
#         "long_name": "\ub300\ud55c\ubbfc\uad6d",
# ...

# %%
for i in range(len(reverse_geocode_result)):
    lat=reverse_geocode_result[i]['geometry']['location']['lat']
    lng=reverse_geocode_result[i]['geometry']['location']['lng']
    new_reverse_geocode_result=  gmaps.reverse_geocode((lat,lng), language='ko')
    print(lat,lng)
    print("\n\n\n\n")
    print(new_reverse_geocode_result)
    print("\n\n\n\n")
# Out:
# 37.5646562 126.976623
#
#
#
#
#
# ...
